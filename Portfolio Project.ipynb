# %% [markdown]
# ## **Michael Buckman**
# ## **MIS 505**
# ## **This notebook contains the code for my Portfolio Project**

# %%
#import libraries for notebook
import sqlite3 # for db connection and SQL
import pandas as pd #to display data for readability
pd.set_option('display.max_rows', None)#show all rows
pd.set_option('display.max_columns', None)#show all columns
import matplotlib.pyplot as plt

# %% [markdown]
# **Read in files and data discovery**

# %%
#read in the first set as e
e = pd.read_csv(r"C:\Users\buckm\PY\CLASS_FILES\MODULE_8\DATA\WDIData.csv")

# %%
#read in the second set as g
g = pd.read_csv(r"C:\Users\buckm\PY\CLASS_FILES\MODULE_8\DATA\API_SE.PRM.ENRL_DS2_en_csv_v2_4538564.csv" , skiprows = 4)

# %%
#review the first set for structure
e.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  1966  1967  1968  1969  1970  1971  1972  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1973  1974  1975  1976  1977  1978  1979  1980  1981  1982  1983  1984  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1985  1986  1987  1988  1989  1990  1991  1992  1993  1994  1995  1996  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1997  1998  1999       2000       2001       2002       2003       2004  \
# 0   NaN   NaN   NaN  11.435351  11.805706  12.167502  12.533893  12.916778
# 1   NaN   NaN   NaN   3.500037   3.692771   3.846867   4.071761   4.314265
# 2   NaN   NaN   NaN  32.330196  32.698002  33.145282  33.676838  34.198090
# 3   NaN   NaN   NaN  19.811283  19.900569  21.525812  22.474309  23.781918
# 4   NaN   NaN   NaN   8.469418        NaN        NaN   9.697171  10.919163
#
#         2005       2006       2007       2008       2009       2010  \
# 0  13.351035  13.865804  14.348658  14.764352  15.226159  15.625978
# 1   4.537563   4.826155   5.042363   5.312541   5.542820   5.808091
# 2  34.721609  35.199741  35.854238  36.242278  36.717076  37.015695
# 3  23.487415  24.763538  26.766518  25.934179  26.181557  27.557137
# 4  10.385696  12.423710  12.431412  12.888967  15.341002  14.577175
#
#         2011       2012       2013       2014       2015       2016  \
# 0  16.128485  16.559819  16.936004  17.337896  17.687093  18.140971
# 1   6.058950   6.281667   6.499471   6.680066   6.859110   7.016238
# 2  37.329561  37.601816  37.855399  38.046781  38.326255  38.468426
# 3  29.089827  31.844384  31.794160  32.001027  33.871910  38.880173
# 4  16.222794  19.402592  18.663502  17.633986  16.464681  24.531436
#
#         2017       2018       2019       2020  2021  Unnamed: 66
# 0  18.491344  18.825520  19.272212  19.628009   NaN          NaN
# 1   7.180364   7.322294   7.517191   7.651598   NaN          NaN
# 2  38.670044  38.722783  38.927016  39.042839   NaN          NaN
# 3  40.261358  43.061877  44.270860  45.803485   NaN          NaN
# 4  25.345111  27.449908  29.641760  30.404935   NaN          NaN

# %%
#pull unique inidcator values in e
e['Indicator Name'].unique()
# Out:
# array(['Access to clean fuels and technologies for cooking (% of population)',
#        'Access to clean fuels and technologies for cooking, rural (% of rural population)',
#        'Access to clean fuels and technologies for cooking, urban (% of urban population)',
#        ...,
#        'Women who were first married by age 18 (% of women ages 20-24)',
#        "Women's share of population ages 15+ living with HIV (%)",
#        'Young people (ages 15-24) newly infected with HIV'],
#       shape=(1442,), dtype=object)

# %%
#review the second set for structure
g.head()
# Out:
#                   Country Name Country Code             Indicator Name  \
# 0                        Aruba          ABW  Primary education, pupils
# 1  Africa Eastern and Southern          AFE  Primary education, pupils
# 2                  Afghanistan          AFG  Primary education, pupils
# 3   Africa Western and Central          AFW  Primary education, pupils
# 4                       Angola          AGO  Primary education, pupils
#
#   Indicator Code  1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  \
# 0    SE.PRM.ENRL   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    SE.PRM.ENRL   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2    SE.PRM.ENRL   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3    SE.PRM.ENRL   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    SE.PRM.ENRL   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#        1970      1971      1972      1973      1974      1975      1976  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  540685.0  572933.0  597509.0  624374.0  654209.0  692342.0  729667.0
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN  434370.0  485955.0  516131.0  576420.0       NaN       NaN
#
#        1977      1978  1979       1980       1981       1982       1983  \
# 0       NaN       NaN   NaN        NaN        NaN        NaN        NaN
# 1       NaN       NaN   NaN        NaN        NaN        NaN        NaN
# 2  764175.0  810657.0   NaN   959583.0  1024741.0   365458.0        NaN
# 3       NaN       NaN   NaN        NaN        NaN        NaN        NaN
# 4       NaN       NaN   NaN  1420839.0  1300673.0  1258858.0  1178430.0
#
#         1984      1985      1986       1987       1988       1989       1990  \
# 0        NaN       NaN       NaN        NaN        NaN        NaN        NaN
# 1        NaN       NaN       NaN        NaN        NaN        NaN        NaN
# 2   447351.0  479150.0  512809.0        NaN   651622.0   622135.0   622513.0
# 3        NaN       NaN       NaN        NaN        NaN        NaN        NaN
# 4  1065025.0  870410.0  974498.0  1012303.0  1031314.0  1067906.0  1041126.0
#
#        1991      1992      1993       1994       1995  1996  1997       1998  \
# 0       NaN       NaN       NaN        NaN        NaN   NaN   NaN        NaN
# 1       NaN       NaN       NaN        NaN        NaN   NaN   NaN        NaN
# 2  627888.0       NaN  786532.0  1161444.0  1312197.0   NaN   NaN  1046338.0
# 3       NaN       NaN       NaN        NaN        NaN   NaN   NaN        NaN
# 4  990155.0  989444.0       NaN        NaN        NaN   NaN   NaN  1342116.0
#
#        1999      2000      2001       2002       2003       2004       2005  \
# 0    9096.0    9263.0    9436.0     9840.0     9897.0    10185.0    10250.0
# 1       NaN       NaN       NaN        NaN        NaN        NaN        NaN
# 2  875605.0  749360.0  773623.0  2667629.0  3781015.0  4430142.0  4318819.0
# 3       NaN       NaN       NaN        NaN        NaN        NaN        NaN
# 4       NaN       NaN       NaN        NaN        NaN        NaN        NaN
#
#         2006       2007       2008       2009       2010       2011  \
# 0    10390.0    10346.0    10012.0     9944.0     9858.0     9112.0
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2  4669110.0  4718077.0  4974836.0  4945632.0  5279326.0  5291624.0
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN  3558605.0  3930051.0  4046266.0  4273006.0  5026803.0
#
#         2012       2013       2014       2015       2016       2017  \
# 0     8888.0     9803.0     9816.0        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2  5767543.0  5986268.0  6217756.0  6199329.0  6265011.0  6350404.0
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN  5620915.0        NaN        NaN
#
#         2018       2019  2020  2021  Unnamed: 66
# 0        NaN        NaN   NaN   NaN          NaN
# 1        NaN        NaN   NaN   NaN          NaN
# 2  6544906.0  6777785.0   NaN   NaN          NaN
# 3        NaN        NaN   NaN   NaN          NaN
# 4        NaN        NaN   NaN   NaN          NaN

# %%
#pull unique inidcator values in g 
g['Indicator Name'].unique()
# Out:
# array(['Primary education, pupils'], dtype=object)

# %% [markdown]
# **Filtering down data**

# %%
#filter e down to GDP inidcators
e_filtered = e[e['Indicator Name'].str.contains('GDP')]
#showcase unique indicators
e_filtered['Indicator Name'].unique()
# Out:
# array(['Agriculture, forestry, and fishing, value added (% of GDP)',
#        'Broad money (% of GDP)',
#        'Central government debt, total (% of GDP)',
#        'Claims on central government, etc. (% GDP)',
#        'Claims on other sectors of the domestic economy (% of GDP)',
#        'CO2 emissions (kg per 2015 US$ of GDP)',
#        'CO2 emissions (kg per 2017 PPP $ of GDP)',
#        'CO2 emissions (kg per PPP $ of GDP)', 'Coal rents (% of GDP)',
#        'Current account balance (% of GDP)',
#        'Current health expenditure (% of GDP)',
#        'Discrepancy in expenditure estimate of GDP (constant LCU)',
#        'Discrepancy in expenditure estimate of GDP (current LCU)',
#        'Domestic credit provided by financial sector (% of GDP)',
#        'Domestic credit to private sector (% of GDP)',
#        'Domestic credit to private sector by banks (% of GDP)',
#        'Domestic general government health expenditure (% of GDP)',
#        'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
#        'Energy use (kg of oil equivalent) per $1,000 GDP (constant 2017 PPP)',
#        'Expense (% of GDP)', 'Exports of goods and services (% of GDP)',
#        'External balance on goods and services (% of GDP)',
#        'Final consumption expenditure (% of GDP)',
#        'Foreign direct investment, net inflows (% of GDP)',
#        'Foreign direct investment, net outflows (% of GDP)',
#        'Forest rents (% of GDP)', 'GDP (constant 2015 US$)',
#        'GDP (constant LCU)', 'GDP (current LCU)', 'GDP (current US$)',
#        'GDP deflator (base year varies by country)',
#        'GDP deflator: linked series (base year varies by country)',
#        'GDP growth (annual %)', 'GDP per capita (constant 2015 US$)',
#        'GDP per capita (constant LCU)', 'GDP per capita (current LCU)',
#        'GDP per capita (current US$)', 'GDP per capita growth (annual %)',
#        'GDP per capita, PPP (constant 2017 international $)',
#        'GDP per capita, PPP (current international $)',
#        'GDP per person employed (constant 2017 PPP $)',
#        'GDP per unit of energy use (constant 2017 PPP $ per kg of oil equivalent)',
#        'GDP per unit of energy use (PPP $ per kg of oil equivalent)',
#        'GDP, PPP (constant 2017 international $)',
#        'GDP, PPP (current international $)',
#        'GDP: linked series (current LCU)',
#        'General government final consumption expenditure (% of GDP)',
#        'Government expenditure on education, total (% of GDP)',
#        'Government expenditure per student, primary (% of GDP per capita)',
#        'Government expenditure per student, secondary (% of GDP per capita)',
#        'Government expenditure per student, tertiary (% of GDP per capita)',
#        'Gross capital formation (% of GDP)',
#        'Gross domestic savings (% of GDP)',
#        'Gross fixed capital formation (% of GDP)',
#        'Gross fixed capital formation, private sector (% of GDP)',
#        'Gross national expenditure (% of GDP)',
#        'Gross savings (% of GDP)',
#        'Households and NPISHs final consumption expenditure (% of GDP)',
#        'Imports of goods and services (% of GDP)',
#        'Industry (including construction), value added (% of GDP)',
#        'Inflation, GDP deflator (annual %)',
#        'Inflation, GDP deflator: linked series (annual %)',
#        'Manufacturing, value added (% of GDP)',
#        'Market capitalization of listed domestic companies (% of GDP)',
#        'Merchandise trade (% of GDP)', 'Military expenditure (% of GDP)',
#        'Mineral rents (% of GDP)',
#        'Monetary Sector credit to private sector (% GDP)',
#        'Natural gas rents (% of GDP)',
#        'Net acquisition of financial assets (% of GDP)',
#        'Net incurrence of liabilities, total (% of GDP)',
#        'Net investment in nonfinancial assets (% of GDP)',
#        'Net lending (+) / net borrowing (-) (% of GDP)',
#        'Oil rents (% of GDP)',
#        'Personal remittances, received (% of GDP)',
#        'PPP conversion factor, GDP (LCU per international $)',
#        'Price level ratio of PPP conversion factor (GDP) to market exchange rate',
#        'Research and development expenditure (% of GDP)',
#        'Revenue, excluding grants (% of GDP)',
#        'Services, value added (% of GDP)',
#        'Stocks traded, total value (% of GDP)', 'Tax revenue (% of GDP)',
#        'Total natural resources rents (% of GDP)', 'Trade (% of GDP)',
#        'Trade in services (% of GDP)',
#        'Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)'],
#       dtype=object)

# %%
#filter down to specific indicator selected for GDP
e_filtered = e_filtered[e_filtered['Indicator Name'] == 'GDP (current US$)']

# %%
#show all countries listed in the set
e_filtered['Country Name'].unique()
# Out:
# array(['Africa Eastern and Southern', 'Africa Western and Central',
#        'Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
#        'Middle East & North Africa',
#        'Middle East & North Africa (excluding high income)',
#        'Middle East & North Africa (IDA & IBRD countries)',
#        'Middle income', 'North America', 'Not classified', 'OECD members',
#        'Other small states', 'Pacific island small states',
#        'Post-demographic dividend', 'Pre-demographic dividend',
#        'Small states', 'South Asia', 'South Asia (IDA & IBRD)',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)',
#        'Sub-Saharan Africa (IDA & IBRD countries)', 'Upper middle income',
#        'World', 'Afghanistan', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The',
#        'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
#        'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Faroe Islands', 'Fiji',
#        'Finland', 'France', 'French Polynesia', 'Gabon', 'Gambia, The',
#        'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland',
#        'Grenada', 'Guam', 'Guatemala', 'Guinea', 'Guinea-Bissau',
#        'Guyana', 'Haiti', 'Honduras', 'Hong Kong SAR, China', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'Iran, Islamic Rep.', 'Iraq',
#        'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        "Korea, Dem. People's Rep.", 'Korea, Rep.', 'Kosovo', 'Kuwait',
#        'Kyrgyz Republic', 'Lao PDR', 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg',
#        'Macao SAR, China', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives',
#        'Mali', 'Malta', 'Marshall Islands', 'Mauritania', 'Mauritius',
#        'Mexico', 'Micronesia, Fed. Sts.', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia',
#        'Nauru', 'Nepal', 'Netherlands', 'New Caledonia', 'New Zealand',
#        'Nicaragua', 'Niger', 'Nigeria', 'North Macedonia',
#        'Northern Mariana Islands', 'Norway', 'Oman', 'Pakistan', 'Palau',
#        'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines',
#        'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Romania',
#        'Russian Federation', 'Rwanda', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovak Republic', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan',
#        'Spain', 'Sri Lanka', 'St. Kitts and Nevis', 'St. Lucia',
#        'St. Martin (French part)', 'St. Vincent and the Grenadines',
#        'Sudan', 'Suriname', 'Sweden', 'Switzerland',
#        'Syrian Arab Republic', 'Tajikistan', 'Tanzania', 'Thailand',
#        'Timor-Leste', 'Togo', 'Tonga', 'Trinidad and Tobago', 'Tunisia',
#        'Turkiye', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu',
#        'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela, RB', 'Vietnam', 'Virgin Islands (U.S.)',
#        'West Bank and Gaza', 'Yemen, Rep.', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
#filter e to the specific selected country, Poland
poland = e_filtered[e_filtered['Country Name'].str.contains('Poland')]
#verify the set has what is needed for GDP
poland.head()
# Out:
#        Country Name Country Code     Indicator Name  Indicator Code  1960  \
# 296077       Poland          POL  GDP (current US$)  NY.GDP.MKTP.CD   NaN
#
#         1961  1962  1963  1964  1965  1966  1967  1968  1969  1970  1971  \
# 296077   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         1972  1973  1974  1975  1976  1977  1978  1979  1980  1981  1982  \
# 296077   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         1983  1984  1985  1986  1987  1988  1989          1990          1991  \
# 296077   NaN   NaN   NaN   NaN   NaN   NaN   NaN  6.597775e+10  8.550094e+10
#
#                 1992          1993          1994          1995          1996  \
# 296077  9.433705e+10  9.604565e+10  1.108034e+11  1.422928e+11  1.601932e+11
#
#                 1997          1998          1999          2000          2001  \
# 296077  1.593578e+11  1.746858e+11  1.700310e+11  1.722195e+11  1.909055e+11
#
#                 2002          2003          2004          2005          2006  \
# 296077  1.990721e+11  2.178273e+11  2.551102e+11  3.061443e+11  3.446220e+11
#
#                 2007          2008          2009          2010          2011  \
# 296077  4.290285e+11  5.336091e+11  4.397375e+11  4.798342e+11  5.283013e+11
#
#                 2012          2013          2014          2015          2016  \
# 296077  4.985236e+11  5.210163e+11  5.424771e+11  4.778119e+11  4.726304e+11
#
#                 2017          2018          2019          2020          2021  \
# 296077  5.265089e+11  5.874117e+11  5.972806e+11  5.966244e+11  6.740483e+11
#
#         Unnamed: 66
# 296077          NaN

# %%
#begin filtering G to the selected country, Brazil
poland_g = g[g['Country Name'] == 'Poland']

# %% [markdown]
# **Restrucuring data**

# %%
#create a variable holding the years we are wanting to look at
years = [str(y) for y in range(2001, 2021)]
#create a variable with the columns we want to keep
select_id = ['Country Name','Country Code','Indicator Name','Indicator Code']
#combine the variables as the variable, select
select = select_id+years

#use the select variable to structure the data to what we want to utilize
poland_structured = poland[select]
#show the structured data to confirm it is what we need
poland_structured.head()
# Out:
#        Country Name Country Code     Indicator Name  Indicator Code  \
# 296077       Poland          POL  GDP (current US$)  NY.GDP.MKTP.CD
#
#                 2001          2002          2003          2004          2005  \
# 296077  1.909055e+11  1.990721e+11  2.178273e+11  2.551102e+11  3.061443e+11
#
#                 2006          2007          2008          2009          2010  \
# 296077  3.446220e+11  4.290285e+11  5.336091e+11  4.397375e+11  4.798342e+11
#
#                 2011          2012          2013          2014          2015  \
# 296077  5.283013e+11  4.985236e+11  5.210163e+11  5.424771e+11  4.778119e+11
#
#                 2016          2017          2018          2019          2020
# 296077  4.726304e+11  5.265089e+11  5.874117e+11  5.972806e+11  5.966244e+11

# %%
#utlize ment to restructure the format of the data so we have years as a value
#this allows us to join the other set on years, once cleaned
poland_melt = poland_structured.melt(
    id_vars=select_id,
    value_vars = years,
    var_name = 'Year',
    value_name = 'GDP'
    )

# %%
#show the set change to make sure it looks correct
poland_melt.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code  Year  \
# 0       Poland          POL  GDP (current US$)  NY.GDP.MKTP.CD  2001
# 1       Poland          POL  GDP (current US$)  NY.GDP.MKTP.CD  2002
# 2       Poland          POL  GDP (current US$)  NY.GDP.MKTP.CD  2003
# 3       Poland          POL  GDP (current US$)  NY.GDP.MKTP.CD  2004
# 4       Poland          POL  GDP (current US$)  NY.GDP.MKTP.CD  2005
#
#             GDP
# 0  1.909055e+11
# 1  1.990721e+11
# 2  2.178273e+11
# 3  2.551102e+11
# 4  3.061443e+11

# %%
#utilize the same method to melt the data into a format we can use
poland_g_melt = poland_g.melt(
    id_vars = select_id,#we can use the same variables for selection as we did prior as they match between sets
    value_vars = years,
    var_name = 'Year',
    value_name = 'Primary education'
)

# %%
poland_g_melt.head()
# Out:
#   Country Name Country Code             Indicator Name Indicator Code  Year  \
# 0       Poland          POL  Primary education, pupils    SE.PRM.ENRL  2001
# 1       Poland          POL  Primary education, pupils    SE.PRM.ENRL  2002
# 2       Poland          POL  Primary education, pupils    SE.PRM.ENRL  2003
# 3       Poland          POL  Primary education, pupils    SE.PRM.ENRL  2004
# 4       Poland          POL  Primary education, pupils    SE.PRM.ENRL  2005
#
#    Primary education
# 0          3221253.0
# 1          3105262.0
# 2          2983070.0
# 3          2855692.0
# 4          2723661.0

# %% [markdown]
# **Merging the data**

# %%
#join the seats as poland_merged on year
merged = pd.merge(poland_g_melt , poland_melt, on ='Year', how = 'inner')

# %%
merged.head()
# Out:
#   Country Name_x Country Code_x           Indicator Name_x Indicator Code_x  \
# 0         Poland            POL  Primary education, pupils      SE.PRM.ENRL
# 1         Poland            POL  Primary education, pupils      SE.PRM.ENRL
# 2         Poland            POL  Primary education, pupils      SE.PRM.ENRL
# 3         Poland            POL  Primary education, pupils      SE.PRM.ENRL
# 4         Poland            POL  Primary education, pupils      SE.PRM.ENRL
#
#    Year  Primary education Country Name_y Country Code_y   Indicator Name_y  \
# 0  2001          3221253.0         Poland            POL  GDP (current US$)
# 1  2002          3105262.0         Poland            POL  GDP (current US$)
# 2  2003          2983070.0         Poland            POL  GDP (current US$)
# 3  2004          2855692.0         Poland            POL  GDP (current US$)
# 4  2005          2723661.0         Poland            POL  GDP (current US$)
#
#   Indicator Code_y           GDP
# 0   NY.GDP.MKTP.CD  1.909055e+11
# 1   NY.GDP.MKTP.CD  1.990721e+11
# 2   NY.GDP.MKTP.CD  2.178273e+11
# 3   NY.GDP.MKTP.CD  2.551102e+11
# 4   NY.GDP.MKTP.CD  3.061443e+11

# %%
#drop unnecessary columns we do not need for the primary set
poland_final = merged.drop(['Country Name_y',	'Country Code_y',	'Indicator Name_y',	'Indicator Code_y',	'Indicator Name_x',	'Indicator Code_x','Country Name_x',	'Country Code_x'] , axis = 1)
#rename column to match. Include  '_' for SQL DB
poland = poland_final.rename(columns = {'Primary education':'Primary_Enrollment'})

# %% [markdown]
# **Final set review**

# %%
#show the final product to varify it is what we are looking for
poland
# Out:
#     Year  Primary_Enrollment           GDP
# 0   2001           3221253.0  1.909055e+11
# 1   2002           3105262.0  1.990721e+11
# 2   2003           2983070.0  2.178273e+11
# 3   2004           2855692.0  2.551102e+11
# 4   2005           2723661.0  3.061443e+11
# 5   2006           2602020.0  3.446220e+11
# 6   2007           2484820.0  4.290285e+11
# 7   2008           2375205.0  5.336091e+11
# 8   2009           2294369.0  4.397375e+11
# 9   2010           2234937.0  4.798342e+11
# 10  2011           2191659.0  5.283013e+11
# 11  2012           2187172.0  4.985236e+11
# 12  2013           2160861.0  5.210163e+11
# 13  2014           2152655.0  5.424771e+11
# 14  2015                 NaN  4.778119e+11
# 15  2016                 NaN  4.726304e+11
# 16  2017           2296529.0  5.265089e+11
# 17  2018           2277483.0  5.874117e+11
# 18  2019           2312509.0  5.972806e+11
# 19  2020                 NaN  5.966244e+11

# %%
#plot the data as a scatter chart to visualize 

#set the size of the chart
plt.figure(figsize=(12,7))
#create the chart itself
scatter = plt.scatter(x=poland['Year'], #setting the x axis as year
                     y=poland['Primary_Enrollment'], #setting the y axis to enrollment
                     c=poland['GDP'], #setting colormapint to GDP
                     cmap='coolwarm')#setting coolwarm to show the GDP changes
#create labels 
plt.xlabel("Year")
plt.ylabel("Primary Education")
plt.title("Poland Primary Education Enrollment by GDP")
plt.colorbar(scatter, label='GDP (in billions USD)')  
#show the chart
plt.show()

# %% [markdown]
# **CSV creation**

# %%
#creata csv of the cleaned data
poland.to_csv(r'C:\Users\buckm\PY\CLASS_FILES\MODULE_8\DATA\poland_primary_enrollment_&_GDP.csv', index=False)

# %% [markdown]
# **Database creation and data import**

# %%
#create db connection 
conn = sqlite3.connect(r'C:\Users\buckm\PY\CLASS_FILES\MODULE_8\DATA\poland.db')
#create object to execute SQL
cur = conn.cursor()

# %%
#create my_table with 3 columns
cur.execute('''
CREATE TABLE IF NOT EXISTS poland(
    Year NUMERIC,
    Primary_Enrollment NUMERIC,
    GDP NUMBERIC
)
''')
conn.commit()

# %%
#create my_table with 3 columns
cur.execute('''
DROP TABLE poland
''')
conn.commit()

# %%
poland.to_sql(
    name='poland',
    con=conn,
    if_exists='append',
    index=False
)
poland
# Out:
#     Year  Primary_Enrollment           GDP
# 0   2001           3221253.0  1.909055e+11
# 1   2002           3105262.0  1.990721e+11
# 2   2003           2983070.0  2.178273e+11
# 3   2004           2855692.0  2.551102e+11
# 4   2005           2723661.0  3.061443e+11
# 5   2006           2602020.0  3.446220e+11
# 6   2007           2484820.0  4.290285e+11
# 7   2008           2375205.0  5.336091e+11
# 8   2009           2294369.0  4.397375e+11
# 9   2010           2234937.0  4.798342e+11
# 10  2011           2191659.0  5.283013e+11
# 11  2012           2187172.0  4.985236e+11
# 12  2013           2160861.0  5.210163e+11
# 13  2014           2152655.0  5.424771e+11
# 14  2015                 NaN  4.778119e+11
# 15  2016                 NaN  4.726304e+11
# 16  2017           2296529.0  5.265089e+11
# 17  2018           2277483.0  5.874117e+11
# 18  2019           2312509.0  5.972806e+11
# 19  2020                 NaN  5.966244e+11

# %%
#execute an SQL query to ensure that the data is in the table
cur.execute('''
SELECT
    *
FROM poland
''')
#for readability, display results in pandas dataframe
#create variable with select
poland_db = cur.fetchall()
#create variable for headers in query
poland_headers = [description[0] for description in cur.description]
#create dataframe using query and headers as column names
pd.DataFrame(poland_db, columns = poland_headers)
# Out:
#     Year  Primary_Enrollment           GDP
# 0   2001           3221253.0  1.909055e+11
# 1   2002           3105262.0  1.990721e+11
# 2   2003           2983070.0  2.178273e+11
# 3   2004           2855692.0  2.551102e+11
# 4   2005           2723661.0  3.061443e+11
# 5   2006           2602020.0  3.446220e+11
# 6   2007           2484820.0  4.290285e+11
# 7   2008           2375205.0  5.336091e+11
# 8   2009           2294369.0  4.397375e+11
# 9   2010           2234937.0  4.798342e+11
# 10  2011           2191659.0  5.283013e+11
# 11  2012           2187172.0  4.985236e+11
# 12  2013           2160861.0  5.210163e+11
# 13  2014           2152655.0  5.424771e+11
# 14  2015                 NaN  4.778119e+11
# 15  2016                 NaN  4.726304e+11
# 16  2017           2296529.0  5.265089e+11
# 17  2018           2277483.0  5.874117e+11
# 18  2019           2312509.0  5.972806e+11
# 19  2020                 NaN  5.966244e+11

# %%
#close connection
conn.close()
